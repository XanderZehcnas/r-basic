# %% [markdown]
# # Diagrama de Caja y Bigotes

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
np.random.seed(19880519)

# %%
dist1 = np.random.rand(50)*100
dist2 = 50*np.ones(25)
dist3 = 100+100*np.random.rand(10)
dist4 = -100*np.random.rand(10)
data = np.concatenate((dist1,dist2,dist3,dist4))

# %%
fig1,ax1 = plt.subplots()
ax1.set_title("Boxplot básico")
ax1.boxplot(data)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e23721b280>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e23721b940>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e236fb5ee0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e23722a040>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e23722a3a0>],
#  'means': []}

# %%
fig2,ax2 = plt.subplots()
ax2.set_title("Boxplot con muescas")
ax2.boxplot(data, notch=True)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e237364940>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e237371040>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e2373645b0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e237371700>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e237371a60>],
#  'means': []}

# %%
green_diamond = dict(markerfacecolor="g", marker="D")
fig3,ax3 = plt.subplots()
ax3.set_title("Boxplot con outliers personalizados")
ax3.boxplot(data, flierprops=green_diamond)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e2376b3c40>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e2376c0340>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e2376b38e0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e2376c0a00>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e2376c0d60>],
#  'means': []}

# %%
fig4,ax4 = plt.subplots()
ax4.set_title("Boxplot con outliers personalizados")
ax4.boxplot(data, showfliers=False)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e23770afa0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e2377186a0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e23770ac10>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e237718d60>],
#  'fliers': [],
#  'means': []}

# %%
red_square = dict(markerfacecolor="r", marker="s")
fig5,ax5 = plt.subplots()
ax5.set_title("Boxplot pers en Horizontal")
ax5.boxplot(data, vert=False, flierprops=red_square)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e23776cd60>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e23777b460>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e23776c9d0>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e23777bb20>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e23777be80>],
#  'means': []}

# %%
red_square = dict(markerfacecolor="r", marker="s")
fig6,ax6 = plt.subplots()
ax6.set_title("Boxplot adaptando whiskers")
ax6.boxplot(data, vert=False, flierprops=red_square, whis=0.75) # Se ajusta bigote
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x1e2377d1310>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x1e2377d19d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x1e2377c3f40>],
#  'medians': [<matplotlib.lines.Line2D at 0x1e2377dd0d0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x1e2377dd430>],
#  'means': []}

# %%
dist1 = np.random.rand(50)*100
dist2 = 40*np.ones(25)
dist3 = 25+100*np.random.rand(10)
dist4 = -100*np.random.rand(10)
data2 = np.concatenate((dist1,dist2,dist3,dist4))

# %%
data.shape = (-1,1)
data2.shape = (-1,1)

# %%
fulldata = [data,data2,data2[::2,0]]

# %%
fig7,ax7 = plt.subplots() #No consigo representar estos datos
ax7.set_title("Boxplot varios datos")
ax7.boxplot(fulldata)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-32-70757dbcd518> in <module>
#       1 fig7,ax7 = plt.subplots()
#       2 ax7.set_title("Boxplot varios datos")
# ----> 3 ax7.boxplot(fulldata)
#       4 plt.show()
#
# D:\Aplicaciones\Professional\anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
#    1436     def inner(ax, *args, data=None, **kwargs):
#    1437         if data is None:
# -> 1438             return func(ax, *map(sanitize_sequence, args), **kwargs)
#    1439
#    1440         bound = new_sig.bind(ax, *args, **kwargs)
#
# ...

# %%
da
